# %%
# Vérifier le code de statut de la réponse
if offre_response.status_code != 200:
    print("Erreur : Impossible d'obtenir les offres d'emploi.")
else:
    # Extraire les offres d'emploi de la réponse
    offres = offre_response.json()["_embedded"]["offres"]

    # Afficher les titres et les URL des offres d'emploi
    for offre in offres:
        titre = offre["intitule"]
        url = offre["origineOffre"]["urlOrigine"]
        print(f"Titre : {titre}")
        print(f"URL : {url}")
        print("")
# Out:
# Erreur : Impossible d'obtenir les offres d'emploi.

# %%
import requests

# Les informations d'authentification pour l'API
client_id = "PAR_ynov_3141bf157b6bfff2eaae5b6e2b056f0502707b9b7056bcbe00acdf8224fff2b1"
client_secret = "9dbcf2bb44219efa2cd94e1dbf397f3f3cb3266e6cb3b2174d720f127bfc851b"

# Les informations pour autoriser le flux OAuth2
oauth_url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=%2Fpartenaire"
oauth_payload = {
    "grant_type": "client_credentials",
    "client_id": client_id,
    "client_secret": client_secret,
    "scope": "api_offresdemploiv2"
}

# Effectuer la demande pour obtenir le jeton d'accès
response = requests.post(oauth_url, data=oauth_payload)

# Vérifier le code de statut de la réponse
if response.status_code != 200:
    print("Erreur : Impossible d'obtenir le jeton d'accès.")
else:
    # Extraire le jeton d'accès de la réponse
    access_token = response.json()["access_token"]
    print(f"Le jeton d'accès est : {access_token}")
# Out:
# Le jeton d'accès est : k-8mP4_MexjdIEj1Z476YwMu4A0

# %%
import requests
import pandas as pd


# Les informations d'authentification pour l'API
client_id = "PAR_ynov_3141bf157b6bfff2eaae5b6e2b056f0502707b9b7056bcbe00acdf8224fff2b1"
client_secret = "9dbcf2bb44219efa2cd94e1dbf397f3f3cb3266e6cb3b2174d720f127bfc851b"

# Les informations de recherche pour les offres d'emploi
offre_url = "https://api.emploi-store.fr/partenaire/offresdemploi/v2/offres/search"
offre_params = {
    "motsCles": "Informatique",
    "lieu": "France",
    "sort": "0"
}

# Obtenir le jeton d'accès en utilisant OAuth2
token_url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=/partenaire"
token_payload = {
    "grant_type": "client_credentials",
    "client_id": client_id,
    "client_secret": client_secret,
    "scope": "application_"+client_id+" api_offresdemploiv2 o2dsoffre"
}
token_response = requests.post(token_url, data=token_payload)
access_token = token_response.json()["access_token"]

# Envoyer la requête de recherche pour les offres d'emploi
offre_headers = {
    "Authorization": f"Bearer {access_token}"
}
offre_response = requests.get(offre_url, params=offre_params, headers=offre_headers)

# %%
# Extraire les offres d'emploi du JSON de la réponse et les normaliser en un dataframe Pandas
offre_data = offre_response.json()["resultats"]

# Afficher les 10 premières offres d'emploi
display(offre_data)
# Out:
# [{'id': '151ZJHL',
#   'intitule': 'Technicien / Technicienne support de proximité en informatique (H/F)',
# ...

# %%
x = offre_response.json()

# %%
x = offre_response.json()
data_list = []
li =  ['intitule','description',"lieuTravail","salaire"]
for e in range(len(x["resultats"])):
    data_dict = {k:x["resultats"][e][k] for k  in li}#x["resultats"][0]
    data_list.append(data_dict)
df = pd.DataFrame(data_list)
print(df.head(20))
   # print("-"*100)
# Out:
#                                              intitule  \
# 0   Technicien / Technicienne support de proximité...
# 1   Technicien / Technicienne système informatique...
# 2    Technicien support informatique - Coiffure (H/F)
# 3   RESPONSABLE DE FORMATION SPECIALITE INFORMATIQ...
# 4   Administrateur systèmes et réseaux informatiqu...
# 5   Technicien informatique industrielle sur Cherb...
# 6     Technicen(ne) de déploiement informatique (H/F)
# 7    Technicien / Technicienne informatique SAV (H/F)
# 8   Reconversion développeur/Informatique - Java -...
# 9   Technicien.ne support de proximité informatiqu...
# 10  Ingénieur / Ingénieure réseau informatique    ...
# 11  Technicien.ne support de proximité informatiqu...
# 12  Technicien / Technicienne informatique        ...
# 13          Technicien maintenance informatique (F/H)
# 14  Ingénieur / Ingénieure système réseau informat...
# 15  Administrateur / Administratrice système infor...
# ...

# %%
li = ['lieuTravail'] 
keys_to_print= ['libelle','latitude',"longitude","codePostal","commune"]

for e in range(len(x["resultats"])):
    lieuTravail_dict = x["resultats"][e]['lieuTravail']
    filtered_dict = {k:v for k, v in lieuTravail_dict.items() if k in keys_to_print}
    #print(filtered_dict)
    print(lieuTravail_dict)
    print("-"*100)
# Out:
# {'libelle': '06 - NICE', 'latitude': 43.712107, 'longitude': 7.250627, 'codePostal': '06000', 'commune': '06088'}
# ----------------------------------------------------------------------------------------------------
# {'libelle': '974 - ST PIERRE', 'latitude': -21.307722, 'longitude': 55.491803, 'codePostal': '97410', 'commune': '97416'}
# ----------------------------------------------------------------------------------------------------
# {'libelle': '69 - LYON 09', 'latitude': 45.783352, 'longitude': 4.811355, 'codePostal': '69009', 'commune': '69389'}
# ----------------------------------------------------------------------------------------------------
# {'libelle': '13 - AIX EN PROVENCE', 'latitude': 43.541369, 'longitude': 5.406124, 'codePostal': '13090', 'commune': '13001'}
# ----------------------------------------------------------------------------------------------------
# ...

# %%
li = ['salaire'] 
keys_to_print= ['libelle']

for e in range(len(x["resultats"])):
    salaire_dict = x["resultats"][e]['salaire']
    filtered_dict2 = {k:v for k, v in salaire_dict.items() if k in keys_to_print}
    print(salaire_dict)
    print("-"*100)
# Out:
# {'libelle': 'Annuel de 24000,00 Euros à 25000,00 Euros sur 12 mois'}
# ----------------------------------------------------------------------------------------------------
# {'libelle': 'Mensuel de 2000,00 Euros à 2300,00 Euros sur 12 mois'}
# ----------------------------------------------------------------------------------------------------
# {'libelle': 'Mensuel de 1836,00 Euros sur 12 mois', 'complement1': 'Restauration'}
# ----------------------------------------------------------------------------------------------------
# {'libelle': 'Annuel de 40000,00 Euros à 44000,00 Euros sur 12 mois'}
# ----------------------------------------------------------------------------------------------------
# {'libelle': 'Annuel de 40000,00 Euros sur 12 mois'}
# ----------------------------------------------------------------------------------------------------
# {'libelle': 'Annuel de 25000,00 Euros à 35000,00 Euros sur 12 mois'}
# ...

# %%
from pprint import pprint
pprint(x["resultats"])
# Out:
# [{'accessibleTH': False,
#   'alternance': False,
#   'appellationlibelle': 'Technicien / Technicienne système informatique',
#   'competences': [{'code': '102175',
#                    'exigence': 'S',
#                    'libelle': 'Réaliser la maintenance de premier niveau'},
#                   {'code': '109971',
#                    'exigence': 'S',
#                    'libelle': "Diagnostiquer la nature et l'origine des "
#                               'incidents et mettre en oeuvre les mesures '
#                               'correctives'},
#                   {'code': '109973',
#                    'exigence': 'S',
#                    'libelle': 'Installer et intégrer le matériel (station, '
#                               'équipement réseau, périphériques, ...) dans '
#                               "l'environnement de production et configurer les "
#                               'ressources logistiques et physiques'},
#                   {'code': '300184',
# ...

# %%
import pandas as pd

combined_data_list = []

for e in range(len(x["resultats"])):
    # Filtrer le dictionnaire 'intitule' et 'description'
    intitule_description_dict = {k: x["resultats"][e][k] for k in ['intitule', 'description']}
    
    # Filtrer le dictionnaire 'lieuTravail'
    lieuTravail_dict = x["resultats"][e]['lieuTravail']
    filtered_lieuTravail_dict = {k:v for k, v in lieuTravail_dict.items() if k in ['libelle', 'latitude', "longitude", "codePostal", "commune"]}
    
    # Filtrer le dictionnaire 'salaire'
    salaire_dict = x["resultats"][e]['salaire']
    filtered_salaire_dict = {k:v for k, v in salaire_dict.items() if k in ['salaire']}
    
    # Combiner les trois dictionnaires filtrés
    combined_dict = {**intitule_description_dict, **filtered_lieuTravail_dict, **filtered_salaire_dict}
    
    # Ajouter le dictionnaire combiné à la liste combined_data_list
    combined_data_list.append(combined_dict)

# Créer un DataFrame avec la liste des dictionnaires combinés
df = pd.DataFrame(combined_data_list)
print(df.head(20))
# Out:
#                                              intitule  \
# 0   Technicien / Technicienne support de proximité...
# 1   Technicien / Technicienne système informatique...
# 2    Technicien support informatique - Coiffure (H/F)
# 3   RESPONSABLE DE FORMATION SPECIALITE INFORMATIQ...
# 4   Administrateur systèmes et réseaux informatiqu...
# 5   Technicien informatique industrielle sur Cherb...
# 6     Technicen(ne) de déploiement informatique (H/F)
# 7    Technicien / Technicienne informatique SAV (H/F)
# 8   Reconversion développeur/Informatique - Java -...
# 9   Technicien.ne support de proximité informatiqu...
# 10  Ingénieur / Ingénieure réseau informatique    ...
# 11  Technicien.ne support de proximité informatiqu...
# 12  Technicien / Technicienne informatique        ...
# 13          Technicien maintenance informatique (F/H)
# 14  Ingénieur / Ingénieure système réseau informat...
# 15  Administrateur / Administratrice système infor...
# ...

# %%
display(df)
# Out:
#                                               intitule  \
# 0    Technicien / Technicienne support de proximité...
# 1    Technicien / Technicienne système informatique...
# 2     Technicien support informatique - Coiffure (H/F)
# 3    RESPONSABLE DE FORMATION SPECIALITE INFORMATIQ...
# 4    Administrateur systèmes et réseaux informatiqu...
# ..                                                 ...
# 145  Ingénieur Informatique Industrielle (57)      ...
# 146  Technicien supérieur en automatisme et informa...
# 147                  Technicien SAV Informatique (H/F)
# 148  Manager de projets informatiques en alternance...
# 149                      Technicien Informatique (h/f)
#
#                                            description               libelle  \
# 0    METALINE ESN spécialisée dans le recrutement d...             06 - NICE
# 1    Nous souhaitons développer notre clientèle sur...       974 - ST PIERRE
# ...

# %%
df.to_csv("PoleEmploiDonner.csv")

# %%
import pandas as pd

combined_data_list = []

for e in range(len(x["resultats"])):
    # Filtrer le dictionnaire 'intitule' et 'description'
    intitule_description_dict = {k: x["resultats"][e][k] for k in ['intitule', 'description']}
    
    # Filtrer le dictionnaire 'lieuTravail'
    lieuTravail_dict = x["resultats"][e]['lieuTravail']
    filtered_lieuTravail_dict = {k:v for k, v in lieuTravail_dict.items() if k in ['libelle', 'latitude', "longitude", "codePostal", "commune"]}
    
    # Filtrer le dictionnaire 'salaire'
    salaire_dict = x["resultats"][e]['salaire']
    filtered_salaire_dict = {k:v for k, v in salaire_dict.items() if k in ['libelle']}
    
    # Combiner les trois dictionnaires filtrés
    combined_dict = {**intitule_description_dict, **filtered_lieuTravail_dict, **filtered_salaire_dict}  # Utilisez filtered_salaire_dict ici
    
    # Ajouter le dictionnaire combiné à la liste combined_data_list
    combined_data_list.append(combined_dict)

# Créer un DataFrame avec la liste des dictionnaires combinés
df = pd.DataFrame(combined_data_list)
display(df)
# Out:
#                                               intitule  \
# 0    Technicien / Technicienne système informatique...
# 1     Technicien support informatique - Coiffure (H/F)
# 2    RESPONSABLE DE FORMATION SPECIALITE INFORMATIQ...
# 3    Administrateur systèmes et réseaux informatiqu...
# 4    Technicien informatique industrielle sur Cherb...
# ..                                                 ...
# 145  Technicien supérieur en automatisme et informa...
# 146                  Technicien SAV Informatique (H/F)
# 147  Manager de projets informatiques en alternance...
# 148                      Technicien Informatique (h/f)
# 149                      Technicien Informatique (h/f)
#
#                                            description  \
# 0    Nous souhaitons développer notre clientèle sur...
# 1    Notre agence spécialisée sur les métiers de la...
# 2    ANVERGURE INTERIM & RECRUTEMENT, cabinet de re...
# 3    Pour ce poste, vos missions sont les suivantes...
# ...

# %%
import pandas as pd

combined_data_list = []

for e in range(len(x["resultats"])):
    # Filtrer le dictionnaire 'intitule' et 'description'
    intitule_description_dict = {k: x["resultats"][e][k] for k in ['intitule', 'description']}
    
    # Filtrer le dictionnaire 'lieuTravail'
    lieuTravail_dict = x["resultats"][e]['lieuTravail']
    filtered_lieuTravail_dict = {k:v for k, v in lieuTravail_dict.items() if k in ['libelle', 'latitude', "longitude", "codePostal", "commune"]}
    
    # Vérifier si la clé 'salaire' est présente dans le dictionnaire
    if 'salaire' in x["resultats"][e]:
        # Filtrer le dictionnaire 'salaire'
        salaire_dict = x["resultats"][e]['salaire']
        filtered_salaire_dict = {k:v for k, v in salaire_dict.items() if k in ['salaire']}
    else:
        # Si la clé 'salaire' n'est pas présente, créer un dictionnaire vide
        filtered_salaire_dict = {'libelle': None}
    
    # Combiner les trois dictionnaires filtrés
    combined_dict = {**intitule_description_dict, **filtered_lieuTravail_dict, **filtered_salaire_dict}
    
    # Ajouter le dictionnaire combiné à la liste combined_data_list
    combined_data_list.append(combined_dict)

# Créer un DataFrame avec la liste des dictionnaires combinés
df = pd.DataFrame(combined_data_list)

# %%
df = df.rename(columns={'libelle': 'libelle'})

# %%
#supprimer les données non text
df['salaire'] = df['salaire'].apply(lambda x: x if isinstance(x, str) else None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'salaire'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
display(df.head(20))
# Out:
#                                              intitule  \
# 0   RESPONSABLE DE FORMATION SPECIALITE INFORMATIQ...
# 1   Administrateur systèmes et réseaux informatiqu...
# 2   Technicien informatique industrielle sur Cherb...
# 3     Technicen(ne) de déploiement informatique (H/F)
# 4    Technicien / Technicienne informatique SAV (H/F)
# 5   Reconversion développeur/Informatique - Java -...
# 6   Technicien.ne support de proximité informatiqu...
# 7   Ingénieur / Ingénieure réseau informatique    ...
# 8   Technicien.ne support de proximité informatiqu...
# 9   Technicien / Technicienne informatique        ...
# 10          Technicien maintenance informatique (F/H)
# 11  Ingénieur / Ingénieure système réseau informat...
# 12  Administrateur / Administratrice système infor...
# 13  Technicien / Technicienne informatique        ...
# 14  Technicien.ne support de proximité informatiqu...
# 15  Administrateur.trice système informatique    (...
# ...

# %%
from pprint import pprint

for e in range(len(x["resultats"])):
    if 'salaire' in x["resultats"][e]:
        salaire_dict = x["resultats"][e]['salaire']
        pprint(salaire_dict)
        print("-" * 50)
# Out:
# {'libelle': 'Annuel de 40000,00 Euros à 44000,00 Euros sur 12 mois'}
# --------------------------------------------------
# {'libelle': 'Annuel de 40000,00 Euros sur 12 mois'}
# --------------------------------------------------
# {'libelle': 'Annuel de 25000,00 Euros à 35000,00 Euros sur 12 mois'}
# --------------------------------------------------
# {'commentaire': 'A négocier', 'complement1': 'Autre'}
# --------------------------------------------------
# {'commentaire': 'Selon profil/expérience + primes+TR', 'complement1': 'Autre'}
# --------------------------------------------------
# {'complement1': 'Chèque repas',
#  'complement2': 'Participation/action',
#  'libelle': 'Annuel de 30000,00 Euros à 35000,00 Euros sur 13 mois'}
# --------------------------------------------------
# {'commentaire': 'Selon profil',
#  'complement1': 'Chèque repas',
#  'complement2': 'Autre'}
# --------------------------------------------------
# ...

# %%
display(df.head(20))
# Out:
#                                              intitule  \
# 0   RESPONSABLE DE FORMATION SPECIALITE INFORMATIQ...
# 1   Administrateur systèmes et réseaux informatiqu...
# 2   Technicien informatique industrielle sur Cherb...
# 3     Technicen(ne) de déploiement informatique (H/F)
# 4    Technicien / Technicienne informatique SAV (H/F)
# 5   Reconversion développeur/Informatique - Java -...
# 6   Technicien.ne support de proximité informatiqu...
# 7   Ingénieur / Ingénieure réseau informatique    ...
# 8   Technicien.ne support de proximité informatiqu...
# 9   Technicien / Technicienne informatique        ...
# 10          Technicien maintenance informatique (F/H)
# 11  Ingénieur / Ingénieure système réseau informat...
# 12  Administrateur / Administratrice système infor...
# 13  Technicien / Technicienne informatique        ...
# 14  Technicien.ne support de proximité informatiqu...
# 15  Administrateur.trice système informatique    (...
# ...

# %%
from pprint import pprint

for e in range(len(x["resultats"])):
    if 'salaire' in x["resultats"][e]:
        salaire_dict = x["resultats"][e]['salaire']
        pprint(salaire_dict)
        print("-" * 50)
# Out:
# {'libelle': 'Annuel de 40000,00 Euros à 44000,00 Euros sur 12 mois'}
# --------------------------------------------------
# {'libelle': 'Annuel de 40000,00 Euros sur 12 mois'}
# --------------------------------------------------
# {'libelle': 'Annuel de 25000,00 Euros à 35000,00 Euros sur 12 mois'}
# --------------------------------------------------
# {'commentaire': 'A négocier', 'complement1': 'Autre'}
# --------------------------------------------------
# {'commentaire': 'Selon profil/expérience + primes+TR', 'complement1': 'Autre'}
# --------------------------------------------------
# {'complement1': 'Chèque repas',
#  'complement2': 'Participation/action',
#  'libelle': 'Annuel de 30000,00 Euros à 35000,00 Euros sur 13 mois'}
# --------------------------------------------------
# {'commentaire': 'Selon profil',
#  'complement1': 'Chèque repas',
#  'complement2': 'Autre'}
# --------------------------------------------------
# ...

# %%
df.colunm()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 df.colunm()
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colunm'

# %%
import pandas as pd

# Créer un DataFrame à partir des données de x["resultats"]
df_resultats = pd.DataFrame(x["resultats"])

# Initialisation de deux listes vides pour stocker les dictionnaires
lieux_travail = []
salaires = []

# Parcourir les offres d'emploi
for e in range(len(x["resultats"])):
    lieuTravail_dict = x["resultats"][e]['lieuTravail']
    filtered_dict = {k:v for k, v in lieuTravail_dict.items() if k in keys_to_print}
    lieux_travail.append(filtered_dict)

    salaire_dict = x["resultats"][e]['salaire']
    filtered_dict2 = {k:v for k, v in salaire_dict.items() if k in keys_to_print}
    salaires.append(filtered_dict2)

# Créer des DataFrames Pandas à partir des listes de dictionnaires
df_lieux_travail = pd.DataFrame(lieux_travail)
df_salaires = pd.DataFrame(salaires)

# Concaténer les DataFrames horizontalement
df = pd.concat([df_resultats, df_lieux_travail, df_salaires], axis=1)

# Afficher les premières lignes du DataFrame
print(df.head())
# Out:
#         id                                           intitule  \
# 0  151YTTY                        Chef de projet informatique
# 1  151YTQH  Ingénieur d'exploitation informatique H/F - Mo...
# 2  151YTKV  Un Agent de supervision technique informatique...
# 3  151YTJL                    Technicien/ne informatique  H/F
# 4  151YSVR  Ingénieur réseaux / Gestion de projet informat...
#
#                                          description  \
# 0  INFORMATIS-TS recrute un Gestionnaire Applicat...
# 1  A compétences égales, le poste est ouvert aux ...
# 2  Le Pôle régional de Formations est rattaché à ...
# 3  Quel est votre rôle?\n\nVous assurez l'assista...
# 4  INFORMATIS-TS recrute des Ingénieurs  Réseaux....
#
#                dateCreation         dateActualisation  \
# 0  2023-03-31T12:29:39.000Z  2023-03-31T12:29:41.000Z
# 1  2023-03-31T12:25:44.000Z  2023-03-31T12:25:47.000Z
# 2  2023-03-31T12:21:19.000Z  2023-03-31T12:21:19.000Z
# ...

# %%
display(df.head(20))
# Out:
#          id                                           intitule  \
# 0   151YTTY                        Chef de projet informatique
# 1   151YTQH  Ingénieur d'exploitation informatique H/F - Mo...
# 2   151YTKV  Un Agent de supervision technique informatique...
# 3   151YTJL                    Technicien/ne informatique  H/F
# 4   151YSVR  Ingénieur réseaux / Gestion de projet informat...
# 5   151YSSD                   Technicien Informatique IT (H/F)
# 6   151YSDV   Développeur / Développeuse informatique    (H/F)
# 7   151YRRR                        Chef de projet informatique
# 8   151YRQW       Technicien Logistique Informatique H/F (H/F)
# 9   151YRJX           Technicien en support informatique (H/F)
# 10  151YQSZ        Automaticien informaticien industriel (H/F)
# 11  151YQHB  Technicien / Technicienne de help desk en info...
# 12  151YPRN         Chef d'équipe - support informatique (H/F)
# 13  151YMWZ  Administrateur systèmes et réseaux informatiqu...
# ...

# %%
x = offre_response.json()

# %%
print(x)
# Out:
# <bound method Response.json of <Response [206]>>

# %%
dic = {"a":5,"B":4,"C":5}
print(dic.get("d","caps"))
# Out:
# caps

# %%
print(df.dtypes)
# Out:
# 0    object
# dtype: object

# %%
df = pd.DataFrame(offre_response)

# %%
print(df)
# Out:
#                                                       0
# 0     b'{"resultats":[{"id":"151YTTY","intitule":"Ch...
# 1     b"icatifs CRM et Marketing.\\n\\nInt\xc3\xa9gr...
# 2     b' activit\xc3\xa9s de maintenance (dont le ma...
# 3     b" plac\xc3\xa9s sous la responsabilit\xc3\xa9...
# 4     b'ar le client en ce qui concerne la qualit\xc...
# ...                                                 ...
# 4809  b'ts":4387},{"valeurPossible":"9","nbResultats...
# 4810  b'gation":[{"valeurPossible":"CC","nbResultats...
# 4811  b'},{"valeurPossible":"E1","nbResultats":27749...
# 4812  b'{"valeurPossible":"FS","nbResultats":165},{"...
# 4813  b'urPossible":"I1","nbResultats":4},{"valeurPo...
#
# [4814 rows x 1 columns]

# %%
print(df.dtypes)
# Out:
# 0    object
# dtype: object

# %%
print(df.columns)
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df.to_csv('offres_emploi2.csv', index=False)

# %%
x["filtresPossibles"]
# Out:
# [{'filtre': 'typeContrat',
#   'agregation': [{'valeurPossible': 'CCE', 'nbResultats': 1},
#    {'valeurPossible': 'CDD', 'nbResultats': 5177},
#    {'valeurPossible': 'CDI', 'nbResultats': 24063},
#    {'valeurPossible': 'DDI', 'nbResultats': 3},
#    {'valeurPossible': 'DIN', 'nbResultats': 1},
#    {'valeurPossible': 'FRA', 'nbResultats': 209},
#    {'valeurPossible': 'LIB', 'nbResultats': 5628},
#    {'valeurPossible': 'MIS', 'nbResultats': 1538},
#    {'valeurPossible': 'SAI', 'nbResultats': 6}]},
#  {'filtre': 'experience',
#   'agregation': [{'valeurPossible': '0', 'nbResultats': 2738},
#    {'valeurPossible': '1', 'nbResultats': 16335},
#    {'valeurPossible': '2', 'nbResultats': 14877},
#    {'valeurPossible': '3', 'nbResultats': 2676}]},
#  {'filtre': 'qualification',
#   'agregation': [{'valeurPossible': '0', 'nbResultats': 4355},
#    {'valeurPossible': '9', 'nbResultats': 7631},
#    {'valeurPossible': 'X', 'nbResultats': 24640}]},
#  {'filtre': 'natureContrat',
# ...

# %%
df = pd.DataFrame(offre_response)

# %%
print(df)
# Out:
#                                               intitule  \
# 0    Technicien chargé d'applications informatiques...
# 1    Ingenieur developpement informatique (C++, Jav...
# 2    Analyste-programmeur / Analyste-programmeuse i...
# 3                        Technicien Informatique (H/F)
# 4    Administrateur /Administratrice réseau informa...
# ..                                                 ...
# 145  Technicien / Technicienne en micro-informatiqu...
# 146  Commercial / Commerciale en Solutions Informat...
# 147  Technicien supérieur / Technicienne supérieure...
# 148  Technicien Support Informatique de Proximité C...
# 149  Chef de Projet Informatique - Responsable Appl...
#
#                                            description  \
# 0    Au sein de la Direction du Numérique en Santé,...
# 1    Rambus, l'un des principaux fournisseurs de pu...
# 2    Spécialiste de la pièce détachée pour poids lo...
# 3    La Fondation Hopale recrute un(e) Technicien(n...
# ...

# %%
print(df['lieuTravail'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 print(df['lieuTravail'])
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'lieuTravail'

# %%
# normaliser les données JSON dans la colonne 'data'
import json
normalized_data = pd.json_normalize(df['lieuTravail'])

# %%
print(df['lieuTravail'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 print(df['lieuTravail'])
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'lieuTravail'

# %%
li =  ['intitule','description',"lieuTravail","salaire"]
for e in range(len(x["resultats"])):
    print({k:x["resultats"][e][k] for k  in li})#x["resultats"][0]
    print("-"*100)

# %%
# extraire le contenu des accolades dans la colonne 'lieuTravail'
#df['lieuTravail'].apply(lambda x: re.findall('\{(.*)\}',x)[0])
df['lieuTravail'] = df['lieuTravail'].astype(str) # conversion de la colonne en str
df['lieuTravail'] = df['lieuTravail'].apply(lambda x: re.findall('\{(.*)\}',x)[0])

# %%
print(df['lieuTravail'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 print(df['lieuTravail'])
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'lieuTravail'

# %%
import requests

# Les informations d'authentification pour l'API
client_id = "PAR_ynov_3141bf157b6bfff2eaae5b6e2b056f0502707b9b7056bcbe00acdf8224fff2b1"
client_secret = "9dbcf2bb44219efa2cd94e1dbf397f3f3cb3266e6cb3b2174d720f127bfc851b"

# Les informations pour autoriser le flux OAuth2
oauth_url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=/partenaire"
oauth_payloaad = {
    "grant_type": "client_credentials",
    "client_id": client_id,
    "client_secret": client_secret,
    "scope": "api_offresdemploiv2"
}

# Effectuer la demande pour obtenir le jeton d'accès
response = requests.post(oauth_url, data=oauth_payload)

# Vérifier le code de statut de la réponse
if response.status_code != 200:
    print("Erreur : Impossible d'obtenir le jeton d'accès.")
else:
    # Extraire le jeton d'accès de la réponse
    access_token = response.json()["access_token"]
    print(f"Le jeton d'accès est : {Vn4LioWbTk7Wp7tRG0gHQ-VTssY}")
# Out:
# Erreur : Impossible d'obtenir le jeton d'accès.

# %%
response.json()
# Out:
# {'error_description': 'Client authentication failed',
#  'error': 'invalid_client'}

# %%
import requests

# Les informations d'authentification pour l'API
client_id = "PAR_ynov_3141bf157b6bfff2eaae5b6e2b056f0502707b9b7056bcbe00acdf8224fff2b1"
client_secret = "9dbcf2bb44219efa2cd94e1dbf397f3f3cb3266e6cb3b2174d720f127bfc851b"

# Les informations pour autoriser le flux OAuth2
oauth_url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=%2Fpartenaire"
oauth_payload = {
    "grant_type": "client_credentials",
    "client_id": client_id,
    "client_secret": client_secret,
    "scope": "api_offresdemploiv2"
}

# Effectuer la demande pour obtenir le jeton d'accès
response = requests.post(oauth_url, data=oauth_payload)

# Vérifier le code de statut de la réponse
if response.status_code != 200:
    print("Erreur : Impossible d'obtenir le jeton d'accès.")
else:
    # Extraire le jeton d'accès de la réponse
    access_token = response.json()["access_token"]
    print(f"Le jeton d'accès est : {access_token}")
# Out:
# Le jeton d'accès est : qXTPJLJ7_uAWC8cROBZJE7R09Rc

# %%
# Out:
# Erreur : Impossible d'obtenir les offres d'emploi.

# %%
import requests

# API CONNECTION #

client_id="PAR_ynov_3141bf157b6bfff2eaae5b6e2b056f0502707b9b7056bcbe00acdf8224fff2b1" # Your API ID Here
client_secret="qXTPJLJ7_uAWC8cROBZJE7R09Rc" # Your API Secret Here
response=requests.post(
    "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token",
    data={
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
        'scope':'api_offresdemploiv1 o2dsoffre application_{}'.format(client_id),
        'realm':'partenaire'
    },
    headers={'Content-Type':'application/x-www-form-urlencoded','Accept':'application/json'}
    , params={"technicalParameters":{"page":1}}
).json()
token=response['access_token']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 19
#       6 client_secret="qXTPJLJ7_uAWC8cROBZJE7R09Rc" # Your API Secret Here
#       7 response=requests.post(
#       8     "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token",
#       9     data={
#    (...)
#      17     , params={"technicalParameters":{"page":1}}
#      18 ).json()
# ---> 19 token=response['access_token']
#
# KeyError: 'access_token'

# %%
# imports 

import pandas as pd
import requests
import json
import numpy
from pandas.io.json import json_normalize
import time

# %%
# API CONNECTION #

client_id="PAR_idedataskills_ff9af1db81dd556671117874e2785cfb7744be3b25148a472f2d29a5b00b4126" # Your API ID Here
client_secret="ea2d066069be79cec2299c0b1081063c7a070b531d36ec6fd7144b74f6ddd5ae" # Your API Secret Here
response=requests.post(
    "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token",
    data={
        'grant_type': 'client_credentials',
        'client_id': client_id,
        'client_secret': client_secret,
        'scope':'api_offresdemploiv1 o2dsoffre application_{}'.format(client_id),
        'realm':'partenaire'
    },
    headers={'Content-Type':'application/x-www-form-urlencoded','Accept':'application/json'}
    , params={"technicalParameters":{"page":1}}
).json()
token=response['access_token']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 17
#       4 client_secret="ea2d066069be79cec2299c0b1081063c7a070b531d36ec6fd7144b74f6ddd5ae" # Your API Secret Here
#       5 response=requests.post(
#       6     "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token",
#       7     data={
#    (...)
#      15     , params={"technicalParameters":{"page":1}}
#      16 ).json()
# ---> 17 token=response['access_token']
#
# KeyError: 'access_token'

# %%
import requests

# Les informations d'authentification pour l'API
client_id = "PAR_ynov_3141bf157b6bfff2eaae5b6e2b056f0502707b9b7056bcbe00acdf8224fff2b1"
client_secret = "9dbcf2bb44219efa2cd94e1dbf397f3f3cb3266e6cb3b2174d720f127bfc851b"

# Les informations de recherche pour les offres d'emploi
offre_url = "https://api.emploi-store.fr/partenaire/offresdemploi/v2/offres/search"
offre_params = {
    "motsCles": "développeur web",
    "lieu": "bordeaux",
    "sort": "-pertinence"
}

# Obtenir le jeton d'accès en utilisant OAuth2
token_url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=/partenaire"
token_payload = {
    "grant_type": "client_credentials",
    "client_id": client_id,
    "client_secret": client_secret,
    "scope": "application_"+client_id+" api_offresdemploiv2 o2dsoffre"
}
token_response = requests.post(token_url, data=token_payload)
access_token = token_response.json()["access_token"]

# Envoyer la requête de recherche pour les offres d'emploi
offre_headers = {
    "Authorization": f"Bearer {access_token}"
}
offre_response = requests.get(offre_url, params=offre_params, headers=offre_headers)

# Vérifier le code de statut de la réponse
if offre_response.status_code != 200:
    print("Erreur : Impossible d'obtenir les offres d'emploi.")
else:
    # Extraire les offres d'emploi de la réponse
    offres = offre_response.json()["_embedded"]["offres"]

    # Afficher les titres et les URL des offres d'emploi
    for offre in offres:
        titre = offre["intitule"]
        url = offre["origineOffre"]["urlOrigine"]
        print(f"Titre : {titre}")
        print(f"URL : {url}")
        print("")

# %%
dic = {"Authorization":'Bearer Vn4LioWbTk7Wp7tRG0gHQ-VTssY',
      "Content-Type": "application/json;charset=UTF-8"}
requests.get('https://api.emploi-store.fr/partenaire/api_offresdemploi/v2/company/?distance=30&amp;latitude=49.119146&amp;rome_codes=M1607',headers=dic)#.json()
# Out:
# <Response [404]>

# %%
import requests
import pandas as pd

# Les informations d'authentification pour l'API
client_id = "PAR_ynov_3141bf157b6bfff2eaae5b6e2b056f0502707b9b7056bcbe00acdf8224fff2b1"
client_secret = "9dbcf2bb44219efa2cd94e1dbf397f3f3cb3266e6cb3b2174d720f127bfc851b"

# Les informations de recherche pour les offres d'emploi
offre_url = "https://api.emploi-store.fr/partenaire/offresdemploi/v2/offres/search"
offre_params = {
    "motsCles": "developpeur informatique",
    "lieu": "paris",
    "sort": "0"
}

# Obtenir le jeton d'accès en utilisant OAuth2
token_url = "https://entreprise.pole-emploi.fr/connexion/oauth2/access_token?realm=/partenaire"
token_payload = {
    "grant_type": "client_credentials",
    "client_id": client_id,
    "client_secret": client_secret,
    "scope": "application_"+client_id+" api_offresdemploiv2 o2dsoffre"
}
token_response = requests.post(token_url, data=token_payload)
access_token = token_response.json()["access_token"]

# Envoyer la requête de recherche pour les offres d'emploi
offre_headers = {
    "Authorization": f"Bearer {access_token}"
}
offre_response = requests.get(offre_url, params=offre_params, headers=offre_headers)
offre_data = offre_response.json()

# Extraire les informations sur les offres d'emploi dans un dataframe pandas
offre_list = offre_data["resultatsOffres"]
offre_df = pd.DataFrame(columns=["Localisation", "Competences", "Date_Publication", "Offre"])
for offre in offre_list:
    offre_df = offre_df.append({
        "Localisation": offre["lieuTravail"]["libelle"],
        "Competences": offre["romeCode"],
        "Date_Publication": offre["dateCreation"],
        "Offre": offre["intitule"]
    }, ignore_index=True)

# Afficher les premières lignes du dataframe
print(offre_df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 35
#      32 offre_data = offre_response.json()
#      34 # Extraire les informations sur les offres d'emploi dans un dataframe pandas
# ---> 35 offre_list = offre_data["resultatsOffres"]
#      36 offre_df = pd.DataFrame(columns=["Localisation", "Competences", "Date_Publication", "Offre"])
#      37 for offre in offre_list:
#
# KeyError: 'resultatsOffres'
